# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
samples = np.random.uniform(0,1,(2,1000))

# %%
np.shape(samples)
# Out:
# (2, 1000)

# %%
plt.plot(samples[0,:], samples[1,:],'.')
plt.show()
